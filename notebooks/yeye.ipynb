# %% [markdown]
# <a href="https://colab.research.google.com/github/sujeet-banerjee/colab-genai-cs-finance-qa-bot/blob/dev1/notebooks/yeye.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
2 + 2
# Out:
# 4
