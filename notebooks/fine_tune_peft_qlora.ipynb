# %% [markdown]
# <a href="https://colab.research.google.com/github/sujeet-banerjee/colab-genai-cs-finance-qa-bot/blob/dev1/notebooks/fine_tune_peft_qlora.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
np.abs(-3)
# Out:
# np.int64(3)
